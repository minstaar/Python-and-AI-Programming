# %% [markdown]
# <a href="https://colab.research.google.com/github/minstaar/Python-and-AI-Programming/blob/main/Pandas_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
f = open('/content/drive/MyDrive/Colab Notebooks/file.txt', 'rt', encoding='utf-8')
for line in f:
  print(line, end="")
# Out:
# 작은 일에 성실한 사람은 큰 일에도 성실하고,
# 작은 일에 정직하지 못한 사람은 큰 일에도 정직하지 못하다.
# 누가복음 16:10
#
# 변함없이 서로 사랑하는 이가 친구이며
# 위급할 때 서로 돕는 이가 형제이다.
# 잠언 17:17

# %%
with open('/content/drive/MyDrive/Colab Notebooks/proverb.txt', 'r', encoding='utf-8') as f:
  for line in f:
    print(line.strip())
# Out:
# 작은 일에 성실한 사람은 큰 일에도 성실하고,
# 작은 일에 정직하지 못한 사람은 큰 일에도 정직하지 못하다.
# 누가복음 16:10
#
# 변함없이 서로 사랑하는 이가 친구이며
# 위급할 때 서로 돕는 이가 형제이다.
# 잠언 17:17

# %%
import os
import glob

for file in glob.glob(os.path.join('*.txt')):
  with open(file, 'r', newline = ' ', encoding = 'UTF8') as filereader:
    for row in filereader:
      print(row.strip())

# %%
str1 = '     hello     '
str2 = '.....hello.....'
print(str1.strip())
print(str2.lstrip('.'))
print(str2.rstrip('.'))
# Out:
# hello
# hello.....
# .....hello

# %%
import pandas as pd

temp_df = pd.read_csv('/content/drive/MyDrive/temperature.csv', engine = 'python', encoding = 'CP949')
temp_df
# Out:
#                  날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0      \t1907-10-01  108.0     13.5      7.9     20.7
# 1      \t1907-10-02  108.0     16.2      7.9     22.0
# 2      \t1907-10-03  108.0     16.2     13.1     21.3
# 3      \t1907-10-04  108.0     16.5     11.2     22.0
# 4      \t1907-10-05  108.0     17.6     10.9     25.4
# ...             ...    ...      ...      ...      ...
# 41638  \t2022-12-05  108.0     -3.1     -7.0      1.9
# 41639  \t2022-12-06  108.0      0.9     -3.9      5.3
# 41640  \t2022-12-07  108.0      4.9      1.2      9.0
# 41641  \t2022-12-08  108.0      3.7      0.1      9.1
# 41642            \t    NaN      NaN      NaN      NaN
#
# [41643 rows x 5 columns]

# %%
import pandas as pd

url = '/content/drive/MyDrive/temperature.csv'
temp_df = pd.read_csv(url, engine = 'python', encoding = 'CP949', sep = ',')
temp_df
# Out:
#                  날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0      \t1907-10-01  108.0     13.5      7.9     20.7
# 1      \t1907-10-02  108.0     16.2      7.9     22.0
# 2      \t1907-10-03  108.0     16.2     13.1     21.3
# 3      \t1907-10-04  108.0     16.5     11.2     22.0
# 4      \t1907-10-05  108.0     17.6     10.9     25.4
# ...             ...    ...      ...      ...      ...
# 41638  \t2022-12-05  108.0     -3.1     -7.0      1.9
# 41639  \t2022-12-06  108.0      0.9     -3.9      5.3
# 41640  \t2022-12-07  108.0      4.9      1.2      9.0
# 41641  \t2022-12-08  108.0      3.7      0.1      9.1
# 41642            \t    NaN      NaN      NaN      NaN
#
# [41643 rows x 5 columns]

# %%
titanic='https://github.com/sehakflower/data/blob/main/titanic.xlsx?raw=true'
titanic=pd.read_excel(titanic,sheet_name='titanic3')
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
temp_df.head(5)
# Out:
#              날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  \t1907-10-01  108.0     13.5      7.9     20.7
# 1  \t1907-10-02  108.0     16.2      7.9     22.0
# 2  \t1907-10-03  108.0     16.2     13.1     21.3
# 3  \t1907-10-04  108.0     16.5     11.2     22.0
# 4  \t1907-10-05  108.0     17.6     10.9     25.4

# %%
temp_df.tail(3)
# Out:
#                  날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 41640  \t2022-12-07  108.0      4.9      1.2      9.0
# 41641  \t2022-12-08  108.0      3.7      0.1      9.1
# 41642            \t    NaN      NaN      NaN      NaN

# %%
print(len(temp_df))
print(temp_df.shape)
# Out:
# 41643
# (41643, 5)

# %%
temp_df.describe()
# Out:
#             지점       평균기온(℃)       최저기온(℃)       최고기온(℃)
# count  41642.0  40886.000000  40883.000000  40883.000000
# mean     108.0     11.781725      7.490913     16.785828
# std        0.0     10.655955     10.883797     10.973214
# min      108.0    -19.200000    -23.100000    -16.300000
# 25%      108.0      2.800000     -1.300000      7.300000
# 50%      108.0     13.000000      8.100000     18.600000
# 75%      108.0     21.200000     17.100000     26.300000
# max      108.0     33.700000     30.300000     39.600000

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41643 entries, 0 to 41642
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       41643 non-null  object
#  1   지점       41642 non-null  float64
#  2   평균기온(℃)  40886 non-null  float64
#  3   최저기온(℃)  40883 non-null  float64
#  4   최고기온(℃)  40883 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 1.6+ MB

# %%
temp_df.columns
# Out:
# Index(['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)'], dtype='object')

# %%
copy = temp_df.copy()
copy.head()
# Out:
#              날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  \t1907-10-01  108.0     13.5      7.9     20.7
# 1  \t1907-10-02  108.0     16.2      7.9     22.0
# 2  \t1907-10-03  108.0     16.2     13.1     21.3
# 3  \t1907-10-04  108.0     16.5     11.2     22.0
# 4  \t1907-10-05  108.0     17.6     10.9     25.4

# %%
add = pd.DataFrame({'날짜':'1907-09-30', '지점':108.0,'평균기온(℃)':15.5,
             '최저기온(℃)':7.5, '최고기온(℃)':20.5}, index = [41643])
pd.concat([copy, add], ignore_index = True)
# Out:
#                  날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0      \t1907-10-01  108.0     13.5      7.9     20.7
# 1      \t1907-10-02  108.0     16.2      7.9     22.0
# 2      \t1907-10-03  108.0     16.2     13.1     21.3
# 3      \t1907-10-04  108.0     16.5     11.2     22.0
# 4      \t1907-10-05  108.0     17.6     10.9     25.4
# ...             ...    ...      ...      ...      ...
# 41639  \t2022-12-06  108.0      0.9     -3.9      5.3
# 41640  \t2022-12-07  108.0      4.9      1.2      9.0
# 41641  \t2022-12-08  108.0      3.7      0.1      9.1
# 41642            \t    NaN      NaN      NaN      NaN
# 41643    1907-09-30  108.0     15.5      7.5     20.5
#
# [41644 rows x 5 columns]

# %%
copy = pd.concat([copy, add], ignore_index = True)
copy.tail(3)
# Out:
#                  날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 41641  \t2022-12-08  108.0      3.7      0.1      9.1
# 41642            \t    NaN      NaN      NaN      NaN
# 41643    1907-09-30  108.0     15.5      7.5     20.5

# %%
temp_df.index
# Out:
# RangeIndex(start=0, stop=41643, step=1)

# %%
temp_df.values
# Out:
# array([['\t1907-10-01', 108.0, 13.5, 7.9, 20.7],
#        ['\t1907-10-02', 108.0, 16.2, 7.9, 22.0],
#        ['\t1907-10-03', 108.0, 16.2, 13.1, 21.3],
#        ...,
#        ['\t2022-12-07', 108.0, 4.9, 1.2, 9.0],
#        ['\t2022-12-08', 108.0, 3.7, 0.1, 9.1],
#        ['\t', nan, nan, nan, nan]], dtype=object)

# %%
mean_temp = temp_df['평균기온(℃)']
print(type(mean_temp))
mean_temp
# Out:
# <class 'pandas.core.series.Series'>
# 0        13.5
# 1        16.2
# 2        16.2
# 3        16.5
# 4        17.6
#          ...
# 41638    -3.1
# 41639     0.9
# 41640     4.9
# 41641     3.7
# 41642     NaN
# Name: 평균기온(℃), Length: 41643, dtype: float64

# %%
temp_df.sort_values(by = ['평균기온(℃)', '최고기온(℃)'], ascending = [True, False])
# Out:
#                  날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 2661   \t1915-01-13  108.0    -19.2    -21.3    -16.3
# 8502   \t1931-01-10  108.0    -18.9    -21.9    -13.0
# 2662   \t1915-01-14  108.0    -18.0    -21.3    -13.8
# 8503   \t1931-01-11  108.0    -17.4    -22.5    -14.7
# 10335  \t1936-01-17  108.0    -16.4    -20.1    -12.0
# ...             ...    ...      ...      ...      ...
# 16428  \t1953-11-27  108.0      NaN      NaN      NaN
# 16429  \t1953-11-28  108.0      NaN      NaN      NaN
# 16430  \t1953-11-29  108.0      NaN      NaN      NaN
# 16431  \t1953-11-30  108.0      NaN      NaN      NaN
# 41642            \t    NaN      NaN      NaN      NaN
#
# [41643 rows x 5 columns]

# %%
temp_df[::3]
# Out:
#                  날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0      \t1907-10-01  108.0     13.5      7.9     20.7
# 3      \t1907-10-04  108.0     16.5     11.2     22.0
# 6      \t1907-10-07  108.0     11.3      6.3     16.1
# 9      \t1907-10-10  108.0     14.2      6.4     24.1
# 12     \t1907-10-13  108.0     13.8      8.3     21.3
# ...             ...    ...      ...      ...      ...
# 41628  \t2022-11-25  108.0     12.3      7.1     17.8
# 41631  \t2022-11-28  108.0     12.3      7.5     15.0
# 41634  \t2022-12-01  108.0     -5.4     -9.4     -1.2
# 41637  \t2022-12-04  108.0     -3.5     -5.2     -0.2
# 41640  \t2022-12-07  108.0      4.9      1.2      9.0
#
# [13881 rows x 5 columns]

# %%
temp_df[temp_df.columns[2]] # temp_df['평균기온(℃)']
# Out:
# 0        13.5
# 1        16.2
# 2        16.2
# 3        16.5
# 4        17.6
#          ...
# 41638    -3.1
# 41639     0.9
# 41640     4.9
# 41641     3.7
# 41642     NaN
# Name: 평균기온(℃), Length: 41643, dtype: float64

# %%
copy = temp_df.copy()
copy = copy.rename(columns = {copy.columns[2]:'temp'})
copy.temp # copy['temp']
# Out:
# 0        13.5
# 1        16.2
# 2        16.2
# 3        16.5
# 4        17.6
#          ...
# 41638    -3.1
# 41639     0.9
# 41640     4.9
# 41641     3.7
# 41642     NaN
# Name: temp, Length: 41643, dtype: float64

# %%
temp_df[temp_df.columns[2]][2:6]
# Out:
# 2    16.2
# 3    16.5
# 4    17.6
# 5    13.0
# Name: 평균기온(℃), dtype: float64

# %%
temp_df[['평균기온(℃)', '최저기온(℃)']]
# Out:
#        평균기온(℃)  최저기온(℃)
# 0         13.5      7.9
# 1         16.2      7.9
# 2         16.2     13.1
# 3         16.5     11.2
# 4         17.6     10.9
# ...        ...      ...
# 41638     -3.1     -7.0
# 41639      0.9     -3.9
# 41640      4.9      1.2
# 41641      3.7      0.1
# 41642      NaN      NaN
#
# [41643 rows x 2 columns]

# %%
temp_df.loc[0:5:2, '평균기온(℃)':'최저기온(℃)']
# Out:
#    평균기온(℃)  최저기온(℃)
# 0     13.5      7.9
# 2     16.2     13.1
# 4     17.6     10.9

# %%
temp_df.iloc[0:5:2, 2:4]
# Out:
#    평균기온(℃)  최저기온(℃)
# 0     13.5      7.9
# 2     16.2     13.1
# 4     17.6     10.9

# %%
temp_df.pivot_table(index = '날짜', columns = '최저기온(℃)', values = '최고기온(℃)', aggfunc = 'count')
# Out:
# 최저기온(℃)       -23.1  -22.5  -22.3  -22.2  -21.9  -21.8  -21.7  -21.5  -21.3  \
# 날짜
# \t1907-10-01    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# \t1907-10-02    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# \t1907-10-03    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# \t1907-10-04    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# \t1907-10-05    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# \t2022-12-04    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# \t2022-12-05    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# \t2022-12-06    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# \t2022-12-07    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# \t2022-12-08    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
temp_df.groupby('평균기온(℃)').count()
# Out:
#          날짜  지점  최저기온(℃)  최고기온(℃)
# 평균기온(℃)
# -19.2     1   1        1        1
# -18.9     1   1        1        1
# -18.0     1   1        1        1
# -17.4     1   1        1        1
# -16.4     3   3        3        3
# ...      ..  ..      ...      ...
#  31.9     1   1        1        1
#  32.6     2   2        2        2
#  33.1     2   2        2        2
#  33.6     1   1        1        1
#  33.7     1   1        1        1
#
# [489 rows x 4 columns]

# %%
temp_df.groupby('평균기온(℃)')[['최고기온(℃)', '최저기온(℃)']].mean()
# Out:
#          최고기온(℃)  최저기온(℃)
# 평균기온(℃)
# -19.2     -16.30   -21.30
# -18.9     -13.00   -21.90
# -18.0     -13.80   -21.30
# -17.4     -14.70   -22.50
# -16.4     -12.90   -19.70
# ...          ...      ...
#  31.9      36.80    27.30
#  32.6      38.25    27.90
#  33.1      38.15    29.05
#  33.6      39.60    27.80
#  33.7      37.90    30.30
#
# [489 rows x 2 columns]

# %%
df = temp_df.groupby(['평균기온(℃)', '최고기온(℃)']).count()
df
# Out:
#                  날짜  지점  최저기온(℃)
# 평균기온(℃) 최고기온(℃)
# -19.2   -16.3     1   1        1
# -18.9   -13.0     1   1        1
# -18.0   -13.8     1   1        1
# -17.4   -14.7     1   1        1
# -16.4   -13.6     1   1        1
# ...              ..  ..      ...
#  32.6    38.3     1   1        1
#  33.1    37.9     1   1        1
#          38.4     1   1        1
#  33.6    39.6     1   1        1
#  33.7    37.9     1   1        1
#
# [19740 rows x 3 columns]

# %%
df.unstack('평균기온(℃)')
# Out:
#            날짜                                                        ...  \
# 평균기온(℃) -19.2 -18.9 -18.0 -17.4 -16.4 -16.1 -15.9 -15.8 -15.7 -15.6  ...
# 최고기온(℃)                                                              ...
# -16.3     1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# -14.7     NaN   NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN  ...
# -13.8     NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# -13.6     NaN   NaN   NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN  ...
# -13.1     NaN   NaN   NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN  ...
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
#  38.0     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#  38.2     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#  38.3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#  38.4     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
df = df.unstack('평균기온(℃)')
df.stack('평균기온(℃)')
df
# Out:
# <ipython-input-90-dd14a26338a3>:2: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack('평균기온(℃)')
#            날짜                                                        ...  \
# 평균기온(℃) -19.2 -18.9 -18.0 -17.4 -16.4 -16.1 -15.9 -15.8 -15.7 -15.6  ...
# 최고기온(℃)                                                              ...
# -16.3     1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# -14.7     NaN   NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN  ...
# -13.8     NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# -13.6     NaN   NaN   NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN  ...
# -13.1     NaN   NaN   NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN  ...
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# ...

# %%
df1 = temp_df[['날짜', '평균기온(℃)']]
df1
# Out:
#                  날짜  평균기온(℃)
# 0      \t1907-10-01     13.5
# 1      \t1907-10-02     16.2
# 2      \t1907-10-03     16.2
# 3      \t1907-10-04     16.5
# 4      \t1907-10-05     17.6
# ...             ...      ...
# 41638  \t2022-12-05     -3.1
# 41639  \t2022-12-06      0.9
# 41640  \t2022-12-07      4.9
# 41641  \t2022-12-08      3.7
# 41642            \t      NaN
#
# [41643 rows x 2 columns]

# %%
df2 = temp_df[['날짜', '최저기온(℃)', '최고기온(℃)']]
df2
# Out:
#                  날짜  최저기온(℃)  최고기온(℃)
# 0      \t1907-10-01      7.9     20.7
# 1      \t1907-10-02      7.9     22.0
# 2      \t1907-10-03     13.1     21.3
# 3      \t1907-10-04     11.2     22.0
# 4      \t1907-10-05     10.9     25.4
# ...             ...      ...      ...
# 41638  \t2022-12-05     -7.0      1.9
# 41639  \t2022-12-06     -3.9      5.3
# 41640  \t2022-12-07      1.2      9.0
# 41641  \t2022-12-08      0.1      9.1
# 41642            \t      NaN      NaN
#
# [41643 rows x 3 columns]

# %%
fruit = pd.DataFrame({'Num':[123, 456, 789, 1011, 1112],
                      'Fruit':['Apple', 'Banana', 'Cherry', 'Lemon', 'Peach']})
fruit
# Out:
#     Num   Fruit
# 0   123   Apple
# 1   456  Banana
# 2   789  Cherry
# 3  1011   Lemon
# 4  1112   Peach

# %%
grade = pd.DataFrame({'Num':[123, 789, 1314],
                      'Grade':['A', 'B', 'C']})
grade
# Out:
#     Num Grade
# 0   123     A
# 1   789     B
# 2  1314     C

# %%
pd.merge(fruit, grade, on = 'Num', how = 'left')
# Out:
#     Num   Fruit Grade
# 0   123   Apple     A
# 1   456  Banana   NaN
# 2   789  Cherry     B
# 3  1011   Lemon   NaN
# 4  1112   Peach   NaN

# %%
pd.merge(fruit, grade, how = 'inner')
# Out:
#    Num   Fruit Grade
# 0  123   Apple     A
# 1  789  Cherry     B

# %%
pd.merge(fruit, grade, how = 'outer')
# Out:
#     Num   Fruit Grade
# 0   123   Apple     A
# 1   456  Banana   NaN
# 2   789  Cherry     B
# 3  1011   Lemon   NaN
# 4  1112   Peach   NaN
# 5  1314     NaN     C

# %%
fruit.join(grade, how = 'left', lsuffix = '_left', rsuffix = '_right')
# Out:
#    Num_left   Fruit  Num_right Grade
# 0       123   Apple      123.0     A
# 1       456  Banana      789.0     B
# 2       789  Cherry     1314.0     C
# 3      1011   Lemon        NaN   NaN
# 4      1112   Peach        NaN   NaN

# %%
temp_df[temp_df['평균기온(℃)'] > 31.5]
# Out:
#                  날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 25438  \t1978-07-29  108.0     31.6     26.2     36.0
# 31276  \t1994-07-23  108.0     32.6     28.0     38.2
# 31277  \t1994-07-24  108.0     33.1     28.1     38.4
# 31278  \t1994-07-25  108.0     31.9     27.3     36.8
# 31279  \t1994-07-26  108.0     31.7     26.9     37.1
# 37863  \t2012-08-04  108.0     31.7     28.2     36.2
# 37864  \t2012-08-05  108.0     31.8     27.5     36.7
# 40041  \t2018-07-22  108.0     31.8     25.3     38.0
# 40042  \t2018-07-23  108.0     31.7     29.2     35.7
# 40049  \t2018-07-30  108.0     31.7     26.2     36.9
# 40050  \t2018-07-31  108.0     32.6     27.8     38.3
# 40051  \t2018-08-01  108.0     33.6     27.8     39.6
# 40052  \t2018-08-02  108.0     33.7     30.3     37.9
# 40053  \t2018-08-03  108.0     33.1     30.0     37.9
# 40064  \t2018-08-14  108.0     31.7     27.7     37.2
# 40065  \t2018-08-15  108.0     31.7     28.3     38.0
# ...

# %%
temp_df.loc[temp_df['평균기온(℃)'] > 31.5, ['날짜', '최고기온(℃)']]
# Out:
#                  날짜  최고기온(℃)
# 25438  \t1978-07-29     36.0
# 31276  \t1994-07-23     38.2
# 31277  \t1994-07-24     38.4
# 31278  \t1994-07-25     36.8
# 31279  \t1994-07-26     37.1
# 37863  \t2012-08-04     36.2
# 37864  \t2012-08-05     36.7
# 40041  \t2018-07-22     38.0
# 40042  \t2018-07-23     35.7
# 40049  \t2018-07-30     36.9
# 40050  \t2018-07-31     38.3
# 40051  \t2018-08-01     39.6
# 40052  \t2018-08-02     37.9
# 40053  \t2018-08-03     37.9
# 40064  \t2018-08-14     37.2
# 40065  \t2018-08-15     38.0
# 40421  \t2019-08-06     36.8
# 41139  \t2021-07-24     36.5

# %%
condition = [38]

temp_df['최고기온(℃)'].isin(condition)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 41638    False
# 41639    False
# 41640    False
# 41641    False
# 41642    False
# Name: 최고기온(℃), Length: 41643, dtype: bool

# %%
temp_df.loc[temp_df['최고기온(℃)'].isin(condition), '최고기온(℃)']
# Out:
# 40041    38.0
# 40065    38.0
# Name: 최고기온(℃), dtype: float64
